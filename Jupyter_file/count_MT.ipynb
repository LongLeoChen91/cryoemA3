# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# h5path="/well/zhang/users/ncz696/autoseg/Standard/zudi2/CI/pytorch_connectomics/datasets/SingleCell/lab_LR_only_cmSolid.h5"

import SimpleITK as sitk

# raw_path_data = "C:/Users/longl/Documents/emA3/Biological_Analysis/IC5_Mito5_S4-lbl.tif"

raw_path_data = "C:/Users/longl/Documents/emA3/Biological_Analysis/CC2_A5_Mitoch-lbl.tif"

# raw_path_data = "/cygdrive/c/Users/longl/Documents/emA3/Biological_Analysis/IC5_Mito5_S4-lbl.tif"

# raw_path_data = "Infected_Cell_5_whole_segmentation.tif"
raw_data_readin= sitk.ReadImage(raw_path_data)
raw_data = sitk.GetArrayFromImage(raw_data_readin)
print(raw_data.shape)


im0 = raw_data

im0_to_count = im0.flatten()

print(im0_to_count.shape)

from collections import Counter
recounted = Counter(im0_to_count)
print(recounted)
# Out:
# (200, 1103, 3070)
# (677242000,)
# ...

# %%
num = []
for k,v in recounted.items():
    print(k,v)
    v0 = np.array(v)
    num=np.append(num,v0)
    
lenth = len(num)
Vol = num[1:lenth]*845*10e-9

print(num)
print(Vol)
# Out:
# 0 654992047
# 1 94441
# 2 2001136
# 3 651893
# 4 61845
# 5 4191
# 6 2671
# 7 9765
# 8 43860
# 9 4037
# 10 1397064
# 11 183117
# 12 136152
# 13 7876
# 14 2713278
# 15 103215
# 16 21237
# 17 20874
# 18 4719369
# 19 88907
# 20 1632
# 21 3321
# 22 1734
# 23 481359
# 24 11948
# 25 3254
# 26 8437
# 27 37154
# 28 10117
# 29 392952
# 30 307654
# 31 143229
# 32 138835
# 33 1383308
# 34 449
# 35 97540
# 36 18528
# 37 13257
# 38 4915
# 39 240
# 40 112950
# 41 95654
# 42 50463
# 43 505
# 44 262017
# 45 1553
# 46 46828
# 47 180178
# 48 114100
# 49 1815
# 50 3884
# 51 20774
# 52 12875
# 53 20519
# 54 2339
# 55 186776
# 56 37932
# 57 4279
# 58 12051
# 59 13540
# 60 12790
# 61 11877
# 62 1745
# 63 14363
# 64 6623
# 65 53900
# 66 1807
# 67 4953
# 68 19282
# 69 3555
# 70 24099
# 71 55731
# 72 47453
# 73 86542
# 74 54973
# 75 7637
# 76 30014
# 77 3123
# 78 9569
# 79 84032
# 80 10717
# 81 5061
# 82 1318
# 83 7879
# 84 6785
# 85 3015
# 86 2906
# 87 33332
# 88 58852
# 89 271520
# 90 7054
# 91 8429
# ...

# %%
import numpy as np
Volum_IC5 = Vol
print(Volum_IC5)

import pandas as pd 
import numpy as np

pd.DataFrame(Vol).to_csv('Volum_CC2_MT.csv')
# Out:
# [7.98026450e-01 1.69095992e+01 5.50849585e+00 5.22590250e-01
#  3.54139500e-02 2.25699500e-02 8.25142500e-02 3.70617000e-01
#  3.41126500e-02 1.18051908e+01 1.54733865e+00 1.15048440e+00
#  6.65522000e-02 2.29271991e+01 8.72166750e-01 1.79452650e-01
#  1.76385300e-01 3.98786681e+01 7.51264150e-01 1.37904000e-02
#  2.80624500e-02 1.46523000e-02 4.06748355e+00 1.00960600e-01
#  2.74963000e-02 7.12926500e-02 3.13951300e-01 8.54886500e-02
#  3.32044440e+00 2.59967630e+00 1.21028505e+00 1.17315575e+00
#  1.16889526e+01 3.79405000e-03 8.24213000e-01 1.56561600e-01
#  1.12021650e-01 4.15317500e-02 2.02800000e-03 9.54427500e-01
#  8.08276300e-01 4.26412350e-01 4.26725000e-03 2.21404365e+00
#  1.31228500e-02 3.95696600e-01 1.52250410e+00 9.64145000e-01
#  1.53367500e-02 3.28198000e-02 1.75540300e-01 1.08793750e-01
#  1.73385550e-01 1.97645500e-02 1.57825720e+00 3.20525400e-01
#  3.61575500e-02 1.01830950e-01 1.14413000e-01 1.08075500e-01
# ...

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# h5path="/well/zhang/users/ncz696/autoseg/Standard/zudi2/CI/pytorch_connectomics/datasets/SingleCell/lab_LR_only_cmSolid.h5"

import SimpleITK as sitk

raw_path_data = "C:/Users/longl/Documents/emA3/Biological_Analysis/IC5_Mito5_S4-lbl.tif"

# raw_path_data = "/cygdrive/c/Users/longl/Documents/emA3/Biological_Analysis/IC5_Mito5_S4-lbl.tif"

# raw_path_data = "Infected_Cell_5_whole_segmentation.tif"
raw_data_readin= sitk.ReadImage(raw_path_data)
raw_data = sitk.GetArrayFromImage(raw_data_readin)
print(raw_data.shape)


im0 = raw_data

im0_to_count = im0.flatten()

print(im0_to_count.shape)

from collections import Counter
recounted = Counter(im0_to_count)
print(recounted)

num = []
for k,v in recounted.items():
    print(k,v)
    v0 = np.array(v)
    num=np.append(num,v0)
    
lenth = len(num)
Vol = num[1:lenth]*845*10e-9

print(num)
print(Vol)

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
df = sns.load_dataset('iris')
print(df)

# Usual boxplot
ax = sns.boxplot(x='species', y='sepal_length', data=df)
 
# Add jitter with the swarmplot function
ax = sns.swarmplot(x='species', y='sepal_length', data=df, color="grey")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

import pandas as pd
df = pd.read_csv('Volum_CC2_IC5_MT.csv')
# print(df.sheet_names)


# boxplot
ax = sns.boxplot(x='cell', y='volum/um^3', data=df)
# add stripplot
# ax = sns.stripplot(x='group', y='value', data=df, color="orange", jitter=0.2, size=2.5)

# add title
plt.title("mitochondria volume", loc="left")
plt.ylim(ymax=6)
# show the graph
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

import pandas as pd
df = pd.read_csv('Volum_CC2_IC5_MT.csv')
# print(df.sheet_names)


# plot violin chart
sns.violinplot( x='group', y='value', data=df)

# add title
plt.title("Violin plot", loc="left")
plt.ylim(ymax=6)

# show the graph
plt.show()

# %%
sns.violinplot( x='group', y='value', data=df)
plt.ylim(ymax=6)
plt.show()

# %%
sns.boxplot(x="group", y="value", data=df)
 
# Calculate number of obs per group & median to position labels
medians = df.groupby(['group'])['value'].median().values
nobs = df.groupby("group").size().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]
 
# Add it to the plot
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    plt.text(pos[tick], medians[tick] + 0.4, nobs[tick], horizontalalignment='center', size='medium', color='w', weight='semibold')

# add title
plt.title("Boxplot with number of observation", loc="left")

# show the graph
plt.show()
